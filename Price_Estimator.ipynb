# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
active = pd.read_csv('cleaned_active')
past = pd.read_csv('cleaned_past')

# %%
active.head()
# Out:
#    Unnamed: 0    SALE TYPE              PROPERTY TYPE                ADDRESS  \
# 0           0  MLS Listing  Single Family Residential     20334 Highpoint Pl
# 1           1  MLS Listing  Single Family Residential  26339 Piazza Di Sarro
# 2           2  MLS Listing  Single Family Residential      20538 Calhaven Dr
# 3           3  MLS Listing  Single Family Residential  19103 Pleasantdale St
# 4           4  MLS Listing                Condo/Co-op    22814 Banyan Pl #12
#
#              CITY  ZIP OR POSTAL CODE     PRICE  BEDS  BATHS  \
# 0  Canyon Country             91351.0  590000.0   4.0    2.0
# 1         Newhall             91321.0  589000.0   3.0    2.5
# 2          Saugus             91390.0  664900.0   5.0    4.0
# 3  Canyon Country             91351.0  435000.0   3.0    1.0
# 4          Saugus             91390.0  400000.0   2.0    2.5
#
#                    LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  \
# 0   CAN1 - Canyon Country 1       1577.0   18386.0      1988.0
# ...

# %%
past.head()
# Out:
#    Unnamed: 0  SALE TYPE              PROPERTY TYPE                   ADDRESS  \
# 0           0  PAST SALE  Single Family Residential  29914 Wisteria Valley Rd
# 1           1  PAST SALE  Single Family Residential           30376 Abelia Rd
# 2           2  PAST SALE  Single Family Residential           14711 Zinnia Ct
# 3           3  PAST SALE  Single Family Residential       29331 Canyon Rim Pl
# 4           4  PAST SALE  Single Family Residential        16530 Fairglade St
#
#              CITY  ZIP OR POSTAL CODE   PRICE  BEDS  BATHS  \
# 0  Canyon Country             91387.0  570000   3.0   2.50
# 1  Canyon Country             91387.0  535000   3.0   2.00
# 2  Canyon Country             91387.0  525000   4.0   2.00
# 3  Canyon Country             91387.0  560000   4.0   2.00
# 4  Canyon Country             91387.0  560000   3.0   1.75
#
#                   LOCATION  SQUARE FEET  LOT SIZE  YEAR BUILT  DAYS ON MARKET  \
# ...
